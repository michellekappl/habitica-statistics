# %%
import pandas as pd
import matplotlib.pyplot as plt

headers = ['name', 'id', 'type', 'date', 'value']
df = pd.read_csv('./habitica.csv', names = headers)

habits = df[df.type == 'habit']
dailies = df[df.type == 'daily']

for val in dailies.values:
    print(val)
# Out:
# ["Weekly: Tell someone how they've made a positive difference for you"
#  '45174109-02aa-4a7d-b90f-2af19c1f9eed' 'daily' '2021-01-02 11:13:42' '0']
# ["Weekly: Tell someone how they've made a positive difference for you"
#  '45174109-02aa-4a7d-b90f-2af19c1f9eed' 'daily' '2021-01-03 01:00:52' '0']
# ["Weekly: Tell someone how they've made a positive difference for you"
#  '45174109-02aa-4a7d-b90f-2af19c1f9eed' 'daily' '2021-01-04 12:11:59' '0']
# ["Weekly: Tell someone how they've made a positive difference for you"
#  '45174109-02aa-4a7d-b90f-2af19c1f9eed' 'daily' '2021-01-05 12:44:53' '1']
# ["Weekly: Tell someone how they've made a positive difference for you"
#  '45174109-02aa-4a7d-b90f-2af19c1f9eed' 'daily' '2021-01-06 02:25:30' '1']
# ["Weekly: Tell someone how they've made a positive difference for you"
#  '45174109-02aa-4a7d-b90f-2af19c1f9eed' 'daily' '2021-01-07 14:07:34' '1']
# ["Weekly: Tell someone how they've made a positive difference for you"
# ...
